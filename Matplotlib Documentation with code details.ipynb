# %% [markdown]
# '''Refrence link :-     https://matplotlib.org/3.2.1/tutorials/introductory/sample_plots.html
#      sample plots of matplotlib.pyplot (mostly)                                     '''
#
#
#
# ##  1.Line plot

# %% [markdown]
# plot()-Here's how to create a line plot with text labels using plot().
#
#
# ##  2. Multiple subplots in one figure
# Multiple axes (i.e. subplots) are created with the subplot() function:
#
# ## 3.Images
# Matplotlib can display images (assuming equally spaced horizontal dimensions) using the imshow() function.
#
# ## 4.Contouring and pseudocolor
# The pcolormesh() function can make a colored representation of a two-dimensional array,
# even if the horizontal dimensions are unevenly spaced. The contour() function is another way to represent the same data:
#
#
# ## 5. Histograms
# The hist() function automatically generates histograms and returns the bin counts or probabilities
#
#
# ## 6.Paths
# You can add arbitrary paths in Matplotlib using the  ### (matplotlib.path) module:
#
# ## 7.Three-dimensional plotBar chartsting¶
# The mplot3d toolkit (see Getting started and 3D plotting) has support
# for simple 3d graphs including surface, wireframe, scatter, and bar charts.
#
#
#  mplot3d toolkit. This toolkit is included with all standard Matplotlib installs.
#
#
# ## 8.Streamplot
# The streamplot() function plots the streamlines of a vector field.
# In addition to simply plotting the streamlines,
# it allows you to map the colors and/or line widths of streamlines to a separate parameter,
# such as the speed or local intensity of the vector field.
#
#
# ## 9.Use the bar() function
# to make bar charts, which includes customizations such as error bars:
#
# You can also create stacked bars (bar_stacked.py), or horizontal bar charts (barh.py).
#
# ## 10.Tables
# The table() function adds a text table to an axes.
#
#
#
# ## 11.GUI widgets
# Matplotlib has basic GUI widgets that are independent of the graphical user interface you are using,
# allowing you to write cross GUI figures and widgets. See matplotlib.widgets and the widget examples.
#
#
# ## 12.Filled curves
# The fill() function lets you plot filled curves and polygons
#
#
# ## 13.Date handling
# You can plot timeseries data with major and minor ticks and custom tick formatters for both.
# See matplotlib.ticker and matplotlib.dates for details and usage.
#
#
# ## 14.Polar plots
# The polar() function generates polar plots.
#
# ## 15.Legends
# The legend() function automatically generates figure legends, with MATLAB-compatible legend-placement functions.
#
# ## 16.TeX-notation for text objects
# Below is a sampling of the many TeX expressions now supported by
# Matplotlib's internal mathtext engine.
# The mathtext module provides TeX style mathematical expressions using FreeType and the DejaVu,
# BaKoMa computer modern, or STIX fonts.
# See the matplotlib.mathtext module for additional details.
#
#
# ## 17.EEG GUI
# You can embed Matplotlib into pygtk, wx, Tk, or Qt applications. Here is a screenshot of an EEG viewer called pbrain.
#
# ../../_images/eeg_small.png
# The lower axes uses specgram() to plot the spectrogram of one of the EEG channels.
